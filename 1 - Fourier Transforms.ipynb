# %% [markdown]
# ## 1. Set Up

# %% [markdown]
# ### 1. Libraries

# %%
import numpy as np

import matplotlib.pyplot as plt

import cv2

# %% [markdown]
# ### 2. Visualization Configuration

# %%
# %matplotlib inline

# %% [markdown]
# ### 3. Data

# %%
image_stripes = cv2.imread('images/stripes.jpg')

image_stripes = cv2.cvtColor(image_stripes, cv2.COLOR_BGR2RGB)

# %%
image_solid = cv2.imread('images/pink_solid.jpg')

image_solid = cv2.cvtColor(image_solid, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### 3. Functions

# %%
def ft_image(norm_image):
    f = np.fft.fft2(norm_image)
    fshift = np.fft.fftshift(f)
    frequency_tx = 20*np.log(np.abs(fshift))
    return frequency_tx

# %% [markdown]
# ## 2. Data Exploration

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

ax1.imshow(image_stripes)
ax2.imshow(image_solid)

# %% [markdown]
# ## 3. Data Preparation

# %% [markdown]
# ### 1. Convert to Grayscale

# %%
gray_stripes = cv2.cvtColor(image_stripes, cv2.COLOR_RGB2GRAY)
gray_solid = cv2.cvtColor(image_solid, cv2.COLOR_RGB2GRAY)

# %% [markdown]
# ### 2. Normalize

# %%
norm_stripes = gray_stripes/255.0
norm_solid = gray_solid/255.0

# %% [markdown]
# ## 4. Apply Fourier Transforms

# %%
f_stripes = ft_image(norm_stripes)
f_solid = ft_image(norm_solid)

# %%
f, (ax1,ax2,ax3,ax4) = plt.subplots(1, 4, figsize=(20,10))

ax1.set_title('Originial Stripes')
ax1.imshow(image_stripes, cmap = 'gray')

ax2.set_title('Frequency Transform Stripes')
ax2.imshow(f_stripes, cmap='gray')

ax3.set_title('Original Solid')
ax3.imshow(image_solid, cmap='gray')

ax4.set_title('Frequency Transform Solid')
ax4.imshow(f_solid, cmap='gray')

# %% [markdown]
# ## 5. Appply Fourier Transform on a New Image

# %%
image = cv2.imread('images/birds.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# %%
norm_image = gray/255.0

# %%
f_image = ft_image(norm_image)

# %%
f, (ax1,ax2) = plt.subplots(1, 2, figsize=(20,10))

ax1.imshow(image)
ax2.imshow(f_image, cmap='gray')
